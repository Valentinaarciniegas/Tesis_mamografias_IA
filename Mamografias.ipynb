# %%
from PIL import Image # PIL: Python image library 
#import cv2 #libreria para tratamiento de imagenes
import numpy as np
import os
from matplotlib import pyplot as plt
import cv2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18512/3185426311.py in <module>
#       4 import os
#       5 from matplotlib import pyplot as plt
# ----> 6 import cv2
#
# ModuleNotFoundError: No module named 'cv2'

# %%
im = Image.open('mdb001.png')
plt.imshow(im, cmap='gray')

# %%
#from PIL import ImageEnhance  
#enh = ImageEnhance.Contrast(im)  
#enh.enhance(1.8).show("30% more contrast")

# Sobel Edge Detection
sobelx = cv2.Sobel(src=im, ddepth=cv2.CV_64F, dx=1, dy=0, ksize=5) # Sobel Edge Detection on the X axis
sobely = cv2.Sobel(src=im, ddepth=cv2.CV_64F, dx=0, dy=1, ksize=5) # Sobel Edge Detection on the Y axis
sobelxy = cv2.Sobel(src=im, ddepth=cv2.CV_64F, dx=1, dy=1, ksize=5) # Combined X and Y Sobel Edge Detection
# Display Sobel Edge Detection Images
cv2.imshow('Sobel X', sobelx)
cv2.waitKey(0)
cv2.imshow('Sobel Y', sobely)
cv2.waitKey(0)
cv2.imshow('Sobel X Y using Sobel() function', sobelxy)
cv2.waitKey(0)

# Canny Edge Detection
edges = cv2.Canny(image=im, threshold1=100, threshold2=200) # Canny Edge Detection
# Display Canny Edge Detection Image
cv2.imshow('Canny Edge Detection', edges)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14792/3998402128.py in <module>
#       4
#       5 # Sobel Edge Detection
# ----> 6 sobelx = cv2.Sobel(src=im, ddepth=cv2.CV_64F, dx=1, dy=0, ksize=5) # Sobel Edge Detection on the X axis
#       7 sobely = cv2.Sobel(src=im, ddepth=cv2.CV_64F, dx=0, dy=1, ksize=5) # Sobel Edge Detection on the Y axis
#       8 sobelxy = cv2.Sobel(src=im, ddepth=cv2.CV_64F, dx=1, dy=1, ksize=5) # Combined X and Y Sobel Edge Detection
#
# NameError: name 'cv2' is not defined

# %% [markdown]
# # Red neuronal para reconocimiento de imagenes

# %%
#importar librerias
#import numpy as np 
import os
import re
#from sklearn.model_selection import train_test_split
#from sklearn.metrics import classification_report
import keras
from keras.utils import to_categorical
from keras.models import Sequential,Input,Model
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.layers.normalization import BatchNormalization
from keras.layers.advanced_activations import LeakyReLU
